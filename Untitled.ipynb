# %%
import pandas as pd

# %%
df_atl = pd.read_excel('data/CurrentSeason/ATL.xlsx', 'Games')
df_atl
# Out:
#     Game       Date  Streak  Pts   Pace    eFG   TOV   ORB    FTR    ORT  \
# 0      1 2023-10-25      -1  110  103.4  0.446  10.0  23.5  0.290  106.4
# 1      2 2023-10-27      -2  120  103.5  0.552  12.3  21.4  0.276  115.9
# 2      3 2023-10-29       1  127  103.2  0.586  14.2  32.5  0.194  123.1
# 3      4 2023-10-30       2  127   95.7  0.640   8.7  12.5  0.198  132.7
# 4      5 2023-11-01       3  130  109.9  0.549  15.9  32.6  0.315  118.3
# 5      6 2023-11-04       4  123   91.6  0.559   9.6  42.2  0.204  134.3
# 6      7 2023-11-06      -1  117  103.0  0.441  11.4  39.7  0.265  113.6
# 7      8 2023-11-09       1  120  103.4  0.571  14.8  21.6  0.271  116.1
# 8      9 2023-11-11      -1  109   99.7  0.540  18.1  31.9  0.172  109.3
# 9     10 2023-11-14       1  126  100.7  0.586  12.5  26.3  0.276  125.1
# 10    11 2023-11-15      -1  114   94.5  0.627  14.8  17.6  0.267  120.6
# 11    12 2023-11-17      -2  116   97.5  0.517  11.3  31.8  0.270  118.9
# ...

# %%
df_atl.columns
# Out:
# Index(['Game', 'Date', 'Streak', 'Pts', 'Pace', 'eFG', 'TOV', 'ORB', 'FTR',
#        'ORT', 'OppID', 'OppPts', 'OppeFG', 'OppTOV', 'OppORB', 'OppFTR',
#        'OppORT', 'Location', 'Target'],
#       dtype='object')
